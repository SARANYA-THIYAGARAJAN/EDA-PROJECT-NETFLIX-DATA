# %% [markdown]
# # TASK

# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\Sansa'

# %%
File=pd.read_csv("C:\\Users\\Sansa\\DATA\\besent assisement test Netflix+Dataset2021.csv")

# %% [markdown]
# # warm up excerise

# %% [markdown]
# #     1.Show top 5 records of the dataset

# %%
File.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# #      2.Show bottom 10 records of the dataset

# %%
File.tail(10)
# Out:
#      Show_Id Category                                    Title  \
# 7779   s7778  TV Show                              Zombie Dumb
# 7780   s7779    Movie                               Zombieland
# 7781   s7780  TV Show                                Zona Rosa
# 7782   s7781    Movie                                      Zoo
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 7779              NaN                                                NaN
# 7780  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %% [markdown]
# #   3.Show no. of rows and columns

# %%
shape=File.shape   #shape showing table rows,cols
print(shape)
print("Rows =",shape[0])
print("Columns =",shape[1])
# Out:
# (7789, 11)
# Rows = 7789
# Columns = 11

# %% [markdown]
# #      4.Show no of total values(elements) in the dataset

# %%
File.size #size display over all element in data
# Out:
# 85679

# %% [markdown]
# #    5.Show the column names of the dataset

# %%
File.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# #     6.Show the data type of the columns of the dataset

# %%
File.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# #    7.Show the indexes, column’s datatypes and memory usage

# %%
File.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
# file['year']=file['year'].astype(int)

# %% [markdown]
# #   TASK 1
#
# ##### Check and show whether there are any duplicate records in the dataset.Remove the duplicates permanently and show the dataset

# %%
file_copy=File.copy()
file_copy
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#CHECK
duplicates=File[File.duplicated()]
duplicates
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#remove duplicates
removed_one=File.drop_duplicates()
print("************************************")
print("Before removing duplicates",File.shape)
print("After removing duplicates",removed_one.shape)
print("************************************")
print()
file=removed_one
print(file)
# Out:
# ************************************
# Before removing duplicates (7789, 11)
# After removing duplicates (7787, 11)
# ************************************
#
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
# ...

# %% [markdown]
# # TASK 2
# ##### Show the null values that are present in the dataset .Show the count of the null values in each column.Create a heatmap and show the null value count

# %%
t1=file.isnull()
t1
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
t2=file.isnull().sum()
print(t2)
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#heatmap
import seaborn as sn
import matplotlib.pyplot as mp
null_data = pd.DataFrame(t2, columns=['Null Count'])
# Create a heatmap to show the null values count
mp.figure(figsize=(12, 6))
heatmap = sn.heatmap(null_data.transpose(), annot=True, cmap="PiYG",linewidths=.5,fmt="d",cbar=False)

# Set the title
mp.title('Heatmap of Null Values Count for Each Column')
mp.show()

# %% [markdown]
# # TASK 3
# #####  For ‘House of Cards’, what is the show id and director name.

# %%
file.loc[file["Title"]=="House of Cards",["Title","Show_Id","Director"]]
# Out:
#                Title Show_Id  \
# 2832  House of Cards   s2833
#
#                                                Director
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# # Task 4
# ##### In which year highest number of tv shows and movies were released.Show the count for individual show them in bar graph as well

# %%
file['year']=pd.to_datetime(file['Release_Date'],errors='coerce').dt.year
#finding over all shows movies relesed  on each year
released_count=file.groupby('year').size().reset_index(name='count of released film and tv shows')
print(released_count)
mp.figure(figsize=(12, 6))
sn.barplot(x='year',y='count of released film and tv shows',data=released_count,color='lightgreen')
mp.title("All Released shows and movies")
# Out:
#       year  count of released film and tv shows
# 0   2008.0                                    2
# 1   2009.0                                    2
# 2   2010.0                                    1
# 3   2011.0                                   13
# 4   2012.0                                    3
# 5   2013.0                                   10
# 6   2014.0                                   24
# 7   2015.0                                   79
# 8   2016.0                                  432
# 9   2017.0                                 1201
# 10  2018.0                                 1661
# 11  2019.0                                 2136
# 12  2020.0                                 2008
# 13  2021.0                                  117
# C:\Users\Sansa\AppData\Local\Temp\ipykernel_40176\287415294.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# finding tv shows
tv_show=file[file["Category"]=='TV Show']
tv_show_count = tv_show.groupby('year').size().reset_index(name='Count of tv shows')
print(tv_show_count)

mp.figure(figsize=(12, 6))
sn.barplot(x='year',y='Count of tv shows',data=tv_show_count,color='skyblue')
mp.title("TV SHOWS COUNT")
# Out:
#      year  Count of tv shows
# 0  2008.0                  1
# 1  2013.0                  4
# 2  2014.0                  5
# 3  2015.0                 21
# 4  2016.0                174
# 5  2017.0                337
# 6  2018.0                406
# 7  2019.0                639
# 8  2020.0                696
# 9  2021.0                 29
# Text(0.5, 1.0, 'TV SHOWS COUNT')

# %%
#finding movies count
movies=file[file["Category"]=='Movie']
movies_count = movies.groupby('year').size().reset_index(name='Count of movies')
print(movies_count)
mp.figure(figsize=(12, 6))
sn.barplot(x='year',y='Count of movies',data=movies_count,color='violet')
mp.title("MOVIES")
# Out:
#       year  Count of movies
# 0   2008.0                1
# 1   2009.0                2
# 2   2010.0                1
# 3   2011.0               13
# 4   2012.0                3
# 5   2013.0                6
# 6   2014.0               19
# 7   2015.0               58
# 8   2016.0              258
# 9   2017.0              864
# 10  2018.0             1255
# 11  2019.0             1497
# 12  2020.0             1312
# 13  2021.0               88
# Text(0.5, 1.0, 'MOVIES')

# %% [markdown]
# # Task 5 :
# ##### How many movies and tv shows are there in the dataset?
# ##### Show the count of movies and tv shows separately.Show them using count plot as well.

# %%
category_count = file['Category'].value_counts() 
print(category_count)
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
mp.figure(figsize=(8, 6)) 
sn.countplot(x='Category', hue='Category', data=file, palette='pastel',width=0.3)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# # Task 6 :
# ### i)Show the movies that were released in the year 2000

# %%
movie_list=file[(file['Category']=='Movie')&(file['year']==2000)]
movie_list
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, year]
# Index: []

# %% [markdown]
# ### ii)Show the title of tv shows that were released only in india

# %%
India_list=file[(file['Category']=='TV Show')&(file['Country']=="India")]
India_list.loc[:,['Title']]
# Out:
#                                    Title
# 86          21 Sarfarosh: Saragarhi 1897
# 132                            7 (Seven)
# 340                         Agent Raghav
# 364                         Akbar Birbal
# 533                  Anjaan: Rural Myths
# ...                                  ...
# 6249                The Creative Indians
# 6400  The Golden Years with Javed Akhtar
# 6469              The House That Made Me
# 7294                          Typewriter
# 7705                     Yeh Meri Family
#
# [71 rows x 1 columns]

# %% [markdown]
# ### iii)Show the Top 10 directors who gave the highest number of TV shows and movies to Netflix.

# %%
director_count = file['Director'].value_counts()
# director_count
count_director=director_count.head(10).reset_index()
count_director
# Out:
#                  Director  count
# 0  Raúl Campos, Jan Suter     18
# 1            Marcus Raboy     16
# 2               Jay Karas     14
# 3     Cathy Garcia-Molina     13
# 4             Jay Chapman     12
# 5         Youssef Chahine     12
# 6         Martin Scorsese     12
# 7        Steven Spielberg     10
# 8            David Dhawan      9
# 9             Hakan Algül      8

# %% [markdown]
# ### iv)Show all the records where “category is movie and type is comedies” or “country is united kingdom”

# %%
file[((file['Category']=='Movie') & (file['Type'].str.contains('Comedies',case=False))) | (file['Country'].str.contains('United Kingdom'))]
# Out:
#      Show_Id Category                                    Title  \
# 18       s19    Movie                                   15-Aug
# 19       s20    Movie                                      '89
# 33       s34    Movie                             #realityhigh
# 34       s35    Movie                                    #Roxy
# 36       s37    Movie                                  #Selfie
# ...      ...      ...                                      ...
# 7774   s7773    Movie        Zipi & Zape y la Isla del Capitan
# 7780   s7779    Movie                               Zombieland
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                 Director                                               Cast  \
# 18    Swapnaneel Jayakar  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# ...

# %% [markdown]
# ### v)In how many movies/shows, Tom Cruise were cast? Show the records as well

# %%
# Filter the records where Tom Cruise is listed as a cast member
tom_cruise_records = file[file['Cast'].str.contains('Tom Cruise', na=False)]
count_tom_cruise=len(tom_cruise_records)
print("*******************")
print(f"The total count of Tom Cruise Casted Movie/Tv Shows :{count_tom_cruise}")
print("*******************")
print(f"The Records are : {tom_cruise_records}")
# Out:
# *******************
# The total count of Tom Cruise Casted Movie/Tv Shows :2
# *******************
# The Records are :      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description    year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# # Task 7:
# ### i)What are all Ratings defined by Netflix?

# %%
ratings=file['Rating'].unique()
ratings
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ###  ii)Distribution of content ratings in a graph

# %%
# Counts each rating
rating_counts = file['Rating'].value_counts().reset_index()
rating_counts.columns = ['Rating', 'Count']

# Create a bar plot for the distribution of ratings
mp.figure(figsize=(12, 6))
sn.barplot(x='Rating', y='Count', data=rating_counts, hue='Rating',palette='viridis')
mp.title('Distribution of Content Ratings on Netflix')
# Out:
# Text(0.5, 1.0, 'Distribution of Content Ratings on Netflix')

# %% [markdown]
# ### iii)Show the ratings and no. of unique ratings

# %%
# Show the number of unique ratings
num_unique_ratings = len(ratings)
print(f"Number of Unique Ratings: {num_unique_ratings}")
# Out:
# Number of Unique Ratings: 15

# %% [markdown]
# ### iv)How many movies got “TV-14” rating in Canada?

# %%
canada_movie_count=file[(file["Rating"]=="TV-14")& (file['Country'].str.contains('Canada', na=False)) & (file["Category"]=="Movie")]
print(f"No.of.rating in canada for TV-14 is:{len(canada_movie_count)}")
# Out:
# No.of.rating in canada for TV-14 is:26

# %% [markdown]
# ### v)How many Tv Shows got rating “R” after year 2018?

# %%
r_rated_tv_shows = file[(file['Rating'] == 'R') & (file['year'] > 2018) & (file['Category'] == 'TV Show')]
len(r_rated_tv_shows)
# Out:
# 1

# %% [markdown]
# # Task 8:
# ### What is the maximum duration of a movie/tv show in Netflix? Show the lowest as well

# %%
#need to split movies and shows
#movies min & max duration
movie = file[file['Duration'].str.contains('min')].copy()
movie['Duration'] = movie['Duration'].str.replace(' min', '').astype(int)
max_movie_duration = movie['Duration'].max() 

min_movie_duration = movie['Duration'].min()
print(f"max_movie_duration:{max_movie_duration} min")
print(f"min_movie_duration:{min_movie_duration} min")
# Out:
# max_movie_duration:312 min
# min_movie_duration:3 min

# %%
show=file[file["Duration"].str.contains("Seasons") |file["Duration"].str.contains("Season")].copy()
show["Duration"]=show["Duration"].str.replace("Seasons","").str.replace("Season","").astype(int)
min_shows=show["Duration"].min()
max_shows=show["Duration"].max()
print(f"min:{min_shows} season")
print(f"max:{max_shows} seasons")
# Out:
# min:1 season
# max:16 seasons

# %% [markdown]
# # Task 9:
# ### i)Which country has the highest no. of .Tv Shows

# %%
tv_shows = file[file['Category'] == 'TV Show'] # Count the number of TV Shows by Country 
tv_shows.loc[:,"Country"] = tv_shows['Country'].str.split(', ')

tv_shows_exploded = tv_shows.explode('Country')


Country_tv_show_counts =tv_shows_exploded['Country'].value_counts()#.reset_index(name="no.of tv shows")
print(Country_tv_show_counts)
# Country_tv_show_counts.columns=["Country","no.of.tv shows"]
highest_country_name = Country_tv_show_counts.idxmax()

highest_country=Country_tv_show_counts.max()

print()
print(f"The Highest no.of.shows has country is:{highest_country_name} no.of shows:{highest_country}")
# Out:
# Country
# United States           866
# United Kingdom          256
# Japan                   184
# South Korea             157
# Canada                  126
#                        ...
# Austria                   1
# Cuba                      1
# Philippines               1
# Syria                     1
# United Arab Emirates      1
# Name: count, Length: 65, dtype: int64
#
# The Highest no.of.shows has country is:United States no.of shows:866

# %% [markdown]
# ### ii)Show all the countries and no .of tv shows in a graph as well

# %%
# Filter only TV Shows 
Country_wise=tv_shows_exploded['Country'].value_counts().reset_index(name="Counts")
Country_wise.columns = ['Country', 'Counts']
Country_wise
mp.figure(figsize=(15, 8))
sn.barplot(x='Country', y='Counts', hue='Country',data=Country_wise, palette='viridis')
mp.xticks(rotation=90, fontsize=9, ha='left');

# %%
#Movie list by country wise
movie_list = file[file['Category'] == 'Movie'] # Count the number of TV Shows by Country 
movie_list.loc[:,"Country"] = movie_list['Country'].str.split(', ')

movie_list_exploded = movie_list.explode('Country')

Country_movie_list_counts =movie_list_exploded['Country'].value_counts().reset_index()

Country_movie_list_counts.columns=['Country', 'Counts']

# %% [markdown]
# ### iii) Compare each countries tv show and movie count and show them in a graph as well

# %% [markdown]
# # type 1 graph

# %%
#comparing using plot
combined_counts = pd.merge(Country_movie_list_counts, Country_tv_show_counts, on='Country', how='outer').fillna(0)
mp.figure(figsize=(20, 10))
bar_width = 0.35 
positions = range(len(combined_counts))
positions1= [p - bar_width/2 for p in positions]
positions2= [p + bar_width/2 for p in positions]

# Plot TV shows 
mp.bar(positions1, combined_counts['no.of.tv shows'], width=bar_width, label='TV Shows', color='purple') 
# Plot Movies 
mp.bar(positions2, combined_counts['Counts'], width=bar_width, label='Movies', color='violet')

mp.title('Number of TV Shows and Movies by Country') 
mp.xticks(positions, combined_counts['Country'], rotation=90,fontsize=9);# Rotate x-axis labels for better readability 
mp.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend outside the plot
mp.tight_layout()

# %% [markdown]
# # type 2 graph

# %%
movie_no=file[file["Category"]=="Movie"]
show_no=file[file["Category"]=="TV Show"]
movie_country=movie_list_exploded.groupby('Country').size().reset_index(name="Counts")#The size() like count() function
show_country=tv_shows_exploded.groupby('Country').size().reset_index(name="Counts")
movie_country['Type'] = 'Movies' 
show_country['Type'] = 'TV Shows' 
concat=pd.concat([movie_country,show_country])
print(concat)

mp.figure(figsize=(20, 18)) 
palette = { 'Movies': 'purple', 'TV Shows': 'violet' }
sn.lineplot(x='Country', y='Counts', hue='Type', data=concat,palette=palette, marker='o')
mp.title("comparison of Tv Shows and Movies in each country")
mp.xticks(rotation=90,fontsize=9,ha='right');

# for index, row in concat.iterrows():
#     mp.text(row['Country'], row['Counts'], str(row['Counts']), color='black', ha='center')
# Out:
#                  Country  Counts      Type
# 0            Afghanistan       1    Movies
# 1                Albania       1    Movies
# 2                Algeria       2    Movies
# 3                 Angola       1    Movies
# 4              Argentina      64    Movies
# ..                   ...     ...       ...
# 60  United Arab Emirates       1  TV Shows
# 61        United Kingdom     256  TV Shows
# 62         United States     866  TV Shows
# 63               Uruguay       1  TV Shows
# 64          West Germany       2  TV Shows
#
# [179 rows x 3 columns]

# %% [markdown]
# # Task 10
# ### i)Sort the dataset by year and show them

# %%
file.sort_values(by='year')
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                          ...                   ...
# 6952   s6951  TV Show                   The Tudors                   NaN
# 6998   s6997  TV Show                The West Wing                   NaN
# 7448   s7447  TV Show                      Vroomiz                   NaN
# 7524   s7523  TV Show   Weird Wonders of the World                   NaN
# 7655   s7654  TV Show            Women Behind Bars                   NaN
#
#                                                    Cast  \
# ...

# %% [markdown]
# ### ii)Show the count of movies/tv shows released in a year in line chart

# %%
movie_cunt=file[file["Category"]=="Movie"]
show_cunt=file[file["Category"]=="TV Show"]
movie_year=movie_cunt.groupby('year').size().reset_index(name="Counts")#The size() like count() function
show_year=show_cunt.groupby('year').size().reset_index(name="Counts")
print("**********Movies_groupby_year************")
print(movie_year)
print("**********TV Shows_groupby_year************")
print(show_year)
movie_year['Type'] = 'Movies' 
show_year['Type'] = 'TV Shows' 

combined_data = pd.concat([movie_year, show_year])
print("**********Movies AND Tv Shows_groupby_year************")
print(combined_data)

mp.figure(figsize=(12, 6)) 
palette = { 'Movies': 'lightgreen', 'TV Shows': 'skyblue' }
sn.lineplot(x='year', y='Counts', hue='Type', data=combined_data,palette=palette, marker='o')
mp.title("comparison of Tv Shows and Movies in a year")
for index, row in combined_data.iterrows():
    mp.text(row['year'], row['Counts'], str(row['Counts']), color='black', ha='center')
# Out:
# **********Movies_groupby_year************
#       year  Counts
# 0   2008.0       1
# 1   2009.0       2
# 2   2010.0       1
# 3   2011.0      13
# 4   2012.0       3
# 5   2013.0       6
# 6   2014.0      19
# 7   2015.0      58
# 8   2016.0     258
# 9   2017.0     864
# 10  2018.0    1255
# 11  2019.0    1497
# 12  2020.0    1312
# 13  2021.0      88
# **********TV Shows_groupby_year************
#      year  Counts
# 0  2008.0       1
# 1  2013.0       4
# 2  2014.0       5
# 3  2015.0      21
# 4  2016.0     174
# 5  2017.0     337
# 6  2018.0     406
# 7  2019.0     639
# 8  2020.0     696
# 9  2021.0      29
# **********Movies AND Tv Shows_groupby_year************
#       year  Counts      Type
# 0   2008.0       1    Movies
# 1   2009.0       2    Movies
# 2   2010.0       1    Movies
# 3   2011.0      13    Movies
# 4   2012.0       3    Movies
# 5   2013.0       6    Movies
# 6   2014.0      19    Movies
# 7   2015.0      58    Movies
# 8   2016.0     258    Movies
# ...

# %% [markdown]
# ### iii)Show the Top 5 directors in the Netflix based on the count of movies/tv shows directed by them.

# %%
# movie_by_dir=file[file["Category"]=="Movie"]
Dir_count_movie = movies["Director"].value_counts().reset_index(name="count of movie by director")#value_counts is always count and display descending order.
print(Dir_count_movie.head())
Dir_count_show=tv_shows["Director"].value_counts().reset_index(name="count of tv show by director")
print(Dir_count_show.head())
# Out:
#                  Director  count of movie by director
# 0  Raúl Campos, Jan Suter                          18
# 1            Marcus Raboy                          15
# 2               Jay Karas                          14
# 3     Cathy Garcia-Molina                          13
# 4         Youssef Chahine                          12
#               Director  count of tv show by director
# 0  Alastair Fothergill                             3
# 1          Shin Won-ho                             2
# 2       Iginio Straffi                             2
# 3      Rob Seidenglanz                             2
# 4          Stan Lathan                             2
